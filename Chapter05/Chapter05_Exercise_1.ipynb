# %%
import skimage.io
import numpy as np
import scipy.ndimage
import matplotlib.pyplot as plt
from functions import *

# %%
path = '../Chapter05/Data/'
D = skimage.io.imread(path + 'DTU_noisy.png').astype(float) / 255.  

# Ground truth 
GT = skimage.io.imread(path + 'DTU.png').astype(float) / 255.
#(mu, S_gt) = np.unique(GT, return_inverse = True)
#S_gt = S_gt.reshape(D.shape)


visualize_the_image(D, 'Noisy Image')
visualize_the_image(GT, 'Ground Truth')

mu_1 = 90/ 255 
mu_2 = 170/ 255
mu = np.array([mu_1, mu_2])
